# %%
from pylatexenc.latexencode import unicode_to_latex

# %%
unicode_to_latex('It can be observed that (½, ½) ∉ R, since ½>(½)', replacement_latex_protection='none')
# Out:
# 'It can be observed that (\\textonehalf, \\textonehalf) \\ensuremath{\\notin} R, since \\textonehalf\\ensuremath{>}(\\textonehalf)'
